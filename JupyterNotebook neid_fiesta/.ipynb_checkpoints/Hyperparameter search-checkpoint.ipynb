# %%
import sys
sys.path.append('../src')

import numpy as np
import matplotlib.pyplot as plt
from PyAstronomy import pyasl
from datetime import datetime

from FIESTA_functions import *
from HARPS_N_functions import *
from NEID_solar_functions import *
from functions import *

# %%
from multiprocessing import Pool
import time
import math
from scipy import optimize
import scipy.optimize as opt

# %%
import tensorflow as tf
import keras
from keras import layers
from keras import models
from keras import utils
from keras.layers import Dense
from keras.models import Sequential
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers import Activation
from keras.regularizers import l2
from keras.optimizers import Adam
from keras.optimizers import RMSprop
from keras import datasets

from keras.callbacks import LearningRateScheduler
from keras.callbacks import History

from keras import losses
from sklearn.utils import shuffle

# print(tf.VERSION)
print(tf.keras.__version__)
# Out:
# 2023-03-14 15:40:42.770785: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-14 15:40:43.172958: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-03-14 15:40:46.966629: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 15:40:47.245037: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 15:40:47.257442: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2.10.0

# %%
#----------------------------------
# Read data
#----------------------------------
RV_FT_k     = np.loadtxt('../lib/FIESTA_daily_output/RV_FT_k.txt')
eRV_FT_k    = np.loadtxt('../lib/FIESTA_daily_output/eRV_FT_k.txt')
ΔRV_k       = np.loadtxt('../lib/FIESTA_daily_output/ΔRV_k.txt')
bjd_daily   = np.loadtxt('../lib/FIESTA_daily_output/bjd_daily.txt')
rv_daily    = np.loadtxt('../lib/FIESTA_daily_output/rv_daily.txt')
σrv_daily   = np.loadtxt('../lib/FIESTA_daily_output/σrv_daily.txt')
A_k         = np.loadtxt('../lib/FIESTA_daily_output/A_k.txt')

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# def model_MLP(X, Y, bjd, σrv, lr_model, epochs=200, learning_rate=2e-4, kk=1):
def model_MLP(X, Y, bjd, σrv, lr_model, epochs=200, learning_rate=2e-4):

    if 0:   
        scaler = StandardScaler()
        scaler.fit_transform(X)
    
    x_train, x_test, y_train, y_test, t_train, t_test, σrv_train, σrv_test = train_test_split(X, Y, bjd, σrv, test_size=0.3, random_state=32)    
    batch_size= x_train.shape[0]
    adam = Adam(learning_rate=learning_rate)

    def custom_mse(y_test, y_pred):
        squared_difference = tf.dtypes.cast(tf.square((y_test - y_pred)/σrv_test), tf.float64) 
        return tf.dtypes.cast(tf.math.reduce_sum(squared_difference)/tf.math.reduce_sum(tf.square(1/σrv_test)), tf.float64)  

    # compile the model
    lr_model.compile(loss=custom_mse,
                  optimizer=adam,
                  metrics=[custom_mse])

    ### Fit the model
    lr_model_history = lr_model.fit(x_train, y_train,
                        batch_size=batch_size,
                        epochs=epochs,
                        verbose=0,
                        # callbacks = [callback],
                        validation_data=(x_test, y_test))
    
    y_pred = lr_model.predict(x_test)

    
    plt.subplots(figsize=(12, 4))
    plt.subplots_adjust(wspace=0.3)

    ax1 = plt.subplot(131)
    ax1.plot(np.sqrt(lr_model_history.history['loss']), 'b', label='train')    
    ax1.plot(np.sqrt(lr_model_history.history['val_loss']), 'r' ,label='test')
    ax1.set_xlabel(r'Epoch')
    ax1.set_ylabel(r'wmse')
    ax1.set_yscale('log')
    ax1.legend()
    # ax1.tick_params(labelsize=20)
    ax1.grid()

    ax2 = plt.subplot(132)
    ax2.plot(t_test, y_test, 'r.', label='test')
    ax2.plot(t_test, y_pred, 'k.', label='pred')
    ax2.set_ylabel('RV [m/s]')
    ax2.legend()

    ax3 = plt.subplot(133)
    ax3.plot(y_test, y_pred, 'b.')
    ax3.set_xlabel('test [m/s]')
    ax3.set_ylabel('pred [m/s]')
    ax3.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], '--')
    plt.show()    

    ave, std = weighted_avg_and_std(y_pred[:,0]-y_test, 1/σrv_test**2)
    print(std)
    
    return lr_model, y_test, y_pred[:,0], σrv_test, t_test, std

# %%
RV_inj = (np.random.random(202)-0.5)*10
np.std(RV_inj)
# Out:
# 2.9330662038998208

# %%
# Add ramdom RV shift 
run = 1
for i in range(run):
    
    X = (RV_FT_k[:5] + RV_inj).T
    Y = RV_inj

    ###################
    # build the model #
    ###################
    input_dim = X.shape[1]
    lr_model = Sequential()
    lr_model.add(Dense(1, kernel_initializer='uniform', activation=tf.keras.activations.linear))
    lr_model, y_test, y_pred, σrv_test, bjd_test, std  = model_MLP(X, Y, bjd_daily, σrv_daily, lr_model, epochs=2000, learning_rate=5e-3)
    # lr_model.get_weights()[0].flatten()
# Out:
# 2/2 [==============================] - 0s 2ms/step
# 1.0092947638113243

# %%
X = (RV_FT_k[:5] + RV_inj).T
Y = RV_inj

# %%
# Use scikit-learn to grid search the batch size and epochs
import numpy as np
import tensorflow as tf
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from scikeras.wrappers import KerasRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.losses import mean_squared_error
# Function to create model, required for KerasClassifier
def create_model():
	# create model
	model = Sequential()
	model.add(Dense(1, input_shape=(5,), activation=tf.keras.activations.linear))
    
    
    # Compile model
	model.compile(loss=mean_squared_error,
                  optimizer='adam',
                  metrics=['mean_squared_error']
                 )
	return model
# fix random seed for reproducibility
seed = 7
tf.random.set_seed(seed)

# create model
model = KerasRegressor(model=create_model, verbose=0)
# define the grid search parameters
batch_size = [10, 50, 100, 202] 
epochs = [500, 1000, 2000]
learn_rate = [0.0001, 0.001, 0.01, 0.1, 0.3]
momentum = [0.0, 0.3, 0.6, 0.9]
param_grid = dict(batch_size=batch_size, epochs=epochs, optimizer__learning_rate=learn_rate, optimizer__momentum=momentum)
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)

grid_result = grid.fit(X, Y)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# 2023-03-14 14:45:51.564654: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.567621: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.585285: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.591776: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.597422: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.598660: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.600969: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.601253: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.602665: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.602724: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.606020: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.611089: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.614921: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.617228: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.618590: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.630528: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.633521: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.641340: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.643399: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.644430: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.646035: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.647409: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.647511: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.649059: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.651167: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.652749: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.655907: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.657293: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.667041: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.684372: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.685846: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.688295: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.701704: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.703519: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.719264: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.725670: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.727103: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.727995: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.745634: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.754497: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.755791: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.764147: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.765556: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.779526: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.780772: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.782196: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.790099: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.795425: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.803006: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.806727: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.814754: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.815942: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.823188: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.825036: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.827309: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.828809: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.829992: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.830078: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.835080: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.836385: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.838554: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.839719: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.840536: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.852006: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.853875: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.860074: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.860817: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.861297: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.864620: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.865855: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.872501: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.873664: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.886805: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.886895: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.888073: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.888376: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.893529: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.894684: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.926959: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.950982: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.951765: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.952212: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.960368: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.962159: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.963568: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.965110: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.973454: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.979342: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.985747: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.985866: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.985877: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.986991: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.987306: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.989046: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.990245: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.993847: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.995155: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.995762: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.997909: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:51.999369: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:52.007478: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:52.009202: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:52.010690: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:52.011596: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:52.012048: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:52.019888: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:52.021311: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:52.023638: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:52.024597: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:52.028701: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:52.032512: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:52.033856: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:52.045424: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:52.046835: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:52.052015: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:52.057463: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:52.058918: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:52.059179: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:52.060707: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:52.062727: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:52.064524: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:52.065418: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:52.066763: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:52.068474: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:52.083821: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:52.087518: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:52.088750: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:52.089657: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:52.091567: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:52.092733: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:52.098824: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:52.100116: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:52.101561: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:45:52.102691: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# ...
# 0.888250 (0.035445) with: {'batch_size': 50, 'epochs': 2000, 'optimizer__learning_rate': 0.1, 'optimizer__momentum': 0.0}
# 0.893572 (0.028158) with: {'batch_size': 50, 'epochs': 2000, 'optimizer__learning_rate': 0.1, 'optimizer__momentum': 0.3}
# 0.893487 (0.029182) with: {'batch_size': 50, 'epochs': 2000, 'optimizer__learning_rate': 0.1, 'optimizer__momentum': 0.6}
# 0.888432 (0.030688) with: {'batch_size': 50, 'epochs': 2000, 'optimizer__learning_rate': 0.1, 'optimizer__momentum': 0.9}
# 0.886475 (0.037062) with: {'batch_size': 50, 'epochs': 2000, 'optimizer__learning_rate': 0.3, 'optimizer__momentum': 0.0}
# 0.894831 (0.025588) with: {'batch_size': 50, 'epochs': 2000, 'optimizer__learning_rate': 0.3, 'optimizer__momentum': 0.3}
# 0.896074 (0.026220) with: {'batch_size': 50, 'epochs': 2000, 'optimizer__learning_rate': 0.3, 'optimizer__momentum': 0.6}
# 0.898482 (0.022914) with: {'batch_size': 50, 'epochs': 2000, 'optimizer__learning_rate': 0.3, 'optimizer__momentum': 0.9}
# 0.420856 (0.427633) with: {'batch_size': 100, 'epochs': 500, 'optimizer__learning_rate': 0.0001, 'optimizer__momentum': 0.0}
# -0.917966 (1.985596) with: {'batch_size': 100, 'epochs': 500, 'optimizer__learning_rate': 0.0001, 'optimizer__momentum': 0.3}
# -0.313536 (1.566266) with: {'batch_size': 100, 'epochs': 500, 'optimizer__learning_rate': 0.0001, 'optimizer__momentum': 0.6}
# -0.836073 (1.290129) with: {'batch_size': 100, 'epochs': 500, 'optimizer__learning_rate': 0.0001, 'optimizer__momentum': 0.9}
# -0.639920 (2.019674) with: {'batch_size': 100, 'epochs': 500, 'optimizer__learning_rate': 0.001, 'optimizer__momentum': 0.0}
# -0.735194 (1.016900) with: {'batch_size': 100, 'epochs': 500, 'optimizer__learning_rate': 0.001, 'optimizer__momentum': 0.3}
# -3.070717 (1.434041) with: {'batch_size': 100, 'epochs': 500, 'optimizer__learning_rate': 0.001, 'optimizer__momentum': 0.6}
# 0.557392 (0.378458) with: {'batch_size': 100, 'epochs': 500, 'optimizer__learning_rate': 0.001, 'optimizer__momentum': 0.9}
# 0.432224 (0.118160) with: {'batch_size': 100, 'epochs': 500, 'optimizer__learning_rate': 0.01, 'optimizer__momentum': 0.0}
# -0.849189 (2.419089) with: {'batch_size': 100, 'epochs': 500, 'optimizer__learning_rate': 0.01, 'optimizer__momentum': 0.3}
# 0.500732 (0.362640) with: {'batch_size': 100, 'epochs': 500, 'optimizer__learning_rate': 0.01, 'optimizer__momentum': 0.6}
# -1.465492 (2.048251) with: {'batch_size': 100, 'epochs': 500, 'optimizer__learning_rate': 0.01, 'optimizer__momentum': 0.9}
# -2.321946 (1.875784) with: {'batch_size': 100, 'epochs': 500, 'optimizer__learning_rate': 0.1, 'optimizer__momentum': 0.0}
# -0.503576 (1.878210) with: {'batch_size': 100, 'epochs': 500, 'optimizer__learning_rate': 0.1, 'optimizer__momentum': 0.3}
# -0.757725 (1.930123) with: {'batch_size': 100, 'epochs': 500, 'optimizer__learning_rate': 0.1, 'optimizer__momentum': 0.6}
# 0.022980 (0.670870) with: {'batch_size': 100, 'epochs': 500, 'optimizer__learning_rate': 0.1, 'optimizer__momentum': 0.9}
# 0.453596 (0.388899) with: {'batch_size': 100, 'epochs': 500, 'optimizer__learning_rate': 0.3, 'optimizer__momentum': 0.0}
# 0.172982 (0.512708) with: {'batch_size': 100, 'epochs': 500, 'optimizer__learning_rate': 0.3, 'optimizer__momentum': 0.3}
# 0.717596 (0.157233) with: {'batch_size': 100, 'epochs': 500, 'optimizer__learning_rate': 0.3, 'optimizer__momentum': 0.6}
# -1.683474 (2.162127) with: {'batch_size': 100, 'epochs': 500, 'optimizer__learning_rate': 0.3, 'optimizer__momentum': 0.9}
# 0.671868 (0.241577) with: {'batch_size': 100, 'epochs': 1000, 'optimizer__learning_rate': 0.0001, 'optimizer__momentum': 0.0}
# 0.847433 (0.093845) with: {'batch_size': 100, 'epochs': 1000, 'optimizer__learning_rate': 0.0001, 'optimizer__momentum': 0.3}
# 0.674605 (0.247946) with: {'batch_size': 100, 'epochs': 1000, 'optimizer__learning_rate': 0.0001, 'optimizer__momentum': 0.6}
# 0.715254 (0.235144) with: {'batch_size': 100, 'epochs': 1000, 'optimizer__learning_rate': 0.0001, 'optimizer__momentum': 0.9}
# 0.860834 (0.036748) with: {'batch_size': 100, 'epochs': 1000, 'optimizer__learning_rate': 0.001, 'optimizer__momentum': 0.0}
# 0.457082 (0.255846) with: {'batch_size': 100, 'epochs': 1000, 'optimizer__learning_rate': 0.001, 'optimizer__momentum': 0.3}
# 0.645497 (0.207708) with: {'batch_size': 100, 'epochs': 1000, 'optimizer__learning_rate': 0.001, 'optimizer__momentum': 0.6}
# 0.886627 (0.018925) with: {'batch_size': 100, 'epochs': 1000, 'optimizer__learning_rate': 0.001, 'optimizer__momentum': 0.9}
# 0.844027 (0.067570) with: {'batch_size': 100, 'epochs': 1000, 'optimizer__learning_rate': 0.01, 'optimizer__momentum': 0.0}
# 0.822196 (0.068987) with: {'batch_size': 100, 'epochs': 1000, 'optimizer__learning_rate': 0.01, 'optimizer__momentum': 0.3}
# 0.819460 (0.041746) with: {'batch_size': 100, 'epochs': 1000, 'optimizer__learning_rate': 0.01, 'optimizer__momentum': 0.6}
# 0.702647 (0.083328) with: {'batch_size': 100, 'epochs': 1000, 'optimizer__learning_rate': 0.01, 'optimizer__momentum': 0.9}
# 0.621904 (0.250401) with: {'batch_size': 100, 'epochs': 1000, 'optimizer__learning_rate': 0.1, 'optimizer__momentum': 0.0}
# 0.576656 (0.351516) with: {'batch_size': 100, 'epochs': 1000, 'optimizer__learning_rate': 0.1, 'optimizer__momentum': 0.3}
# 0.855962 (0.094506) with: {'batch_size': 100, 'epochs': 1000, 'optimizer__learning_rate': 0.1, 'optimizer__momentum': 0.6}
# 0.896096 (0.027413) with: {'batch_size': 100, 'epochs': 1000, 'optimizer__learning_rate': 0.1, 'optimizer__momentum': 0.9}
# 0.810316 (0.098087) with: {'batch_size': 100, 'epochs': 1000, 'optimizer__learning_rate': 0.3, 'optimizer__momentum': 0.0}
# 0.844714 (0.045040) with: {'batch_size': 100, 'epochs': 1000, 'optimizer__learning_rate': 0.3, 'optimizer__momentum': 0.3}
# 0.780171 (0.107730) with: {'batch_size': 100, 'epochs': 1000, 'optimizer__learning_rate': 0.3, 'optimizer__momentum': 0.6}
# 0.798631 (0.125823) with: {'batch_size': 100, 'epochs': 1000, 'optimizer__learning_rate': 0.3, 'optimizer__momentum': 0.9}
# 0.884452 (0.029714) with: {'batch_size': 100, 'epochs': 2000, 'optimizer__learning_rate': 0.0001, 'optimizer__momentum': 0.0}
# 0.889098 (0.024971) with: {'batch_size': 100, 'epochs': 2000, 'optimizer__learning_rate': 0.0001, 'optimizer__momentum': 0.3}
# 0.889860 (0.015804) with: {'batch_size': 100, 'epochs': 2000, 'optimizer__learning_rate': 0.0001, 'optimizer__momentum': 0.6}
# 0.855775 (0.089298) with: {'batch_size': 100, 'epochs': 2000, 'optimizer__learning_rate': 0.0001, 'optimizer__momentum': 0.9}
# 0.903028 (0.019127) with: {'batch_size': 100, 'epochs': 2000, 'optimizer__learning_rate': 0.001, 'optimizer__momentum': 0.0}
# 0.887446 (0.021341) with: {'batch_size': 100, 'epochs': 2000, 'optimizer__learning_rate': 0.001, 'optimizer__momentum': 0.3}
# 0.887433 (0.030992) with: {'batch_size': 100, 'epochs': 2000, 'optimizer__learning_rate': 0.001, 'optimizer__momentum': 0.6}
# 0.876394 (0.046458) with: {'batch_size': 100, 'epochs': 2000, 'optimizer__learning_rate': 0.001, 'optimizer__momentum': 0.9}
# 0.870042 (0.053229) with: {'batch_size': 100, 'epochs': 2000, 'optimizer__learning_rate': 0.01, 'optimizer__momentum': 0.0}
# 0.872529 (0.036323) with: {'batch_size': 100, 'epochs': 2000, 'optimizer__learning_rate': 0.01, 'optimizer__momentum': 0.3}
# 0.895066 (0.027497) with: {'batch_size': 100, 'epochs': 2000, 'optimizer__learning_rate': 0.01, 'optimizer__momentum': 0.6}
# 0.899150 (0.023131) with: {'batch_size': 100, 'epochs': 2000, 'optimizer__learning_rate': 0.01, 'optimizer__momentum': 0.9}
# 0.873385 (0.049489) with: {'batch_size': 100, 'epochs': 2000, 'optimizer__learning_rate': 0.1, 'optimizer__momentum': 0.0}
# 0.894791 (0.025541) with: {'batch_size': 100, 'epochs': 2000, 'optimizer__learning_rate': 0.1, 'optimizer__momentum': 0.3}
# 0.892279 (0.016954) with: {'batch_size': 100, 'epochs': 2000, 'optimizer__learning_rate': 0.1, 'optimizer__momentum': 0.6}
# 0.885043 (0.035281) with: {'batch_size': 100, 'epochs': 2000, 'optimizer__learning_rate': 0.1, 'optimizer__momentum': 0.9}
# 0.890354 (0.021444) with: {'batch_size': 100, 'epochs': 2000, 'optimizer__learning_rate': 0.3, 'optimizer__momentum': 0.0}
# 0.900662 (0.026014) with: {'batch_size': 100, 'epochs': 2000, 'optimizer__learning_rate': 0.3, 'optimizer__momentum': 0.3}
# 0.888097 (0.037653) with: {'batch_size': 100, 'epochs': 2000, 'optimizer__learning_rate': 0.3, 'optimizer__momentum': 0.6}
# 0.885306 (0.033484) with: {'batch_size': 100, 'epochs': 2000, 'optimizer__learning_rate': 0.3, 'optimizer__momentum': 0.9}
# -6.936194 (7.757452) with: {'batch_size': 202, 'epochs': 500, 'optimizer__learning_rate': 0.0001, 'optimizer__momentum': 0.0}
# -8.274162 (8.051309) with: {'batch_size': 202, 'epochs': 500, 'optimizer__learning_rate': 0.0001, 'optimizer__momentum': 0.3}
# -8.356176 (5.673187) with: {'batch_size': 202, 'epochs': 500, 'optimizer__learning_rate': 0.0001, 'optimizer__momentum': 0.6}
# -1.137899 (2.803633) with: {'batch_size': 202, 'epochs': 500, 'optimizer__learning_rate': 0.0001, 'optimizer__momentum': 0.9}
# -0.068940 (0.401292) with: {'batch_size': 202, 'epochs': 500, 'optimizer__learning_rate': 0.001, 'optimizer__momentum': 0.0}
# -0.595271 (1.524750) with: {'batch_size': 202, 'epochs': 500, 'optimizer__learning_rate': 0.001, 'optimizer__momentum': 0.3}
# -5.819171 (4.319285) with: {'batch_size': 202, 'epochs': 500, 'optimizer__learning_rate': 0.001, 'optimizer__momentum': 0.6}
# -5.547796 (4.297434) with: {'batch_size': 202, 'epochs': 500, 'optimizer__learning_rate': 0.001, 'optimizer__momentum': 0.9}
# -14.653478 (10.927024) with: {'batch_size': 202, 'epochs': 500, 'optimizer__learning_rate': 0.01, 'optimizer__momentum': 0.0}
# 0.764123 (0.110697) with: {'batch_size': 202, 'epochs': 500, 'optimizer__learning_rate': 0.01, 'optimizer__momentum': 0.3}
# -11.139913 (7.310568) with: {'batch_size': 202, 'epochs': 500, 'optimizer__learning_rate': 0.01, 'optimizer__momentum': 0.6}
# -0.976637 (2.005629) with: {'batch_size': 202, 'epochs': 500, 'optimizer__learning_rate': 0.01, 'optimizer__momentum': 0.9}
# -6.525571 (9.131726) with: {'batch_size': 202, 'epochs': 500, 'optimizer__learning_rate': 0.1, 'optimizer__momentum': 0.0}
# -5.579038 (8.659877) with: {'batch_size': 202, 'epochs': 500, 'optimizer__learning_rate': 0.1, 'optimizer__momentum': 0.3}
# -7.583611 (6.633607) with: {'batch_size': 202, 'epochs': 500, 'optimizer__learning_rate': 0.1, 'optimizer__momentum': 0.6}
# 0.819546 (0.100523) with: {'batch_size': 202, 'epochs': 500, 'optimizer__learning_rate': 0.1, 'optimizer__momentum': 0.9}
# 0.163301 (0.522839) with: {'batch_size': 202, 'epochs': 500, 'optimizer__learning_rate': 0.3, 'optimizer__momentum': 0.0}
# -11.936591 (12.181789) with: {'batch_size': 202, 'epochs': 500, 'optimizer__learning_rate': 0.3, 'optimizer__momentum': 0.3}
# -12.383992 (14.358542) with: {'batch_size': 202, 'epochs': 500, 'optimizer__learning_rate': 0.3, 'optimizer__momentum': 0.6}
# -1.596233 (2.571374) with: {'batch_size': 202, 'epochs': 500, 'optimizer__learning_rate': 0.3, 'optimizer__momentum': 0.9}
# -0.038864 (1.063611) with: {'batch_size': 202, 'epochs': 1000, 'optimizer__learning_rate': 0.0001, 'optimizer__momentum': 0.0}
# -2.502894 (1.270119) with: {'batch_size': 202, 'epochs': 1000, 'optimizer__learning_rate': 0.0001, 'optimizer__momentum': 0.3}
# -0.690564 (0.942205) with: {'batch_size': 202, 'epochs': 1000, 'optimizer__learning_rate': 0.0001, 'optimizer__momentum': 0.6}
# 0.719728 (0.146666) with: {'batch_size': 202, 'epochs': 1000, 'optimizer__learning_rate': 0.0001, 'optimizer__momentum': 0.9}
# -0.462403 (1.371257) with: {'batch_size': 202, 'epochs': 1000, 'optimizer__learning_rate': 0.001, 'optimizer__momentum': 0.0}
# -0.057639 (1.303590) with: {'batch_size': 202, 'epochs': 1000, 'optimizer__learning_rate': 0.001, 'optimizer__momentum': 0.3}
# -2.189364 (2.601449) with: {'batch_size': 202, 'epochs': 1000, 'optimizer__learning_rate': 0.001, 'optimizer__momentum': 0.6}
# 0.701090 (0.128342) with: {'batch_size': 202, 'epochs': 1000, 'optimizer__learning_rate': 0.001, 'optimizer__momentum': 0.9}
# -0.094857 (1.063261) with: {'batch_size': 202, 'epochs': 1000, 'optimizer__learning_rate': 0.01, 'optimizer__momentum': 0.0}
# -0.420015 (0.638680) with: {'batch_size': 202, 'epochs': 1000, 'optimizer__learning_rate': 0.01, 'optimizer__momentum': 0.3}
# -0.561374 (1.886733) with: {'batch_size': 202, 'epochs': 1000, 'optimizer__learning_rate': 0.01, 'optimizer__momentum': 0.6}
# 0.014005 (1.080065) with: {'batch_size': 202, 'epochs': 1000, 'optimizer__learning_rate': 0.01, 'optimizer__momentum': 0.9}
# 0.738476 (0.099850) with: {'batch_size': 202, 'epochs': 1000, 'optimizer__learning_rate': 0.1, 'optimizer__momentum': 0.0}
# 0.365682 (0.643017) with: {'batch_size': 202, 'epochs': 1000, 'optimizer__learning_rate': 0.1, 'optimizer__momentum': 0.3}
# 0.337632 (0.543602) with: {'batch_size': 202, 'epochs': 1000, 'optimizer__learning_rate': 0.1, 'optimizer__momentum': 0.6}
# -0.756509 (1.907994) with: {'batch_size': 202, 'epochs': 1000, 'optimizer__learning_rate': 0.1, 'optimizer__momentum': 0.9}
# 0.732410 (0.173005) with: {'batch_size': 202, 'epochs': 1000, 'optimizer__learning_rate': 0.3, 'optimizer__momentum': 0.0}
# -0.368880 (1.675524) with: {'batch_size': 202, 'epochs': 1000, 'optimizer__learning_rate': 0.3, 'optimizer__momentum': 0.3}
# 0.512256 (0.113940) with: {'batch_size': 202, 'epochs': 1000, 'optimizer__learning_rate': 0.3, 'optimizer__momentum': 0.6}
# -0.949811 (2.239073) with: {'batch_size': 202, 'epochs': 1000, 'optimizer__learning_rate': 0.3, 'optimizer__momentum': 0.9}
# 0.842196 (0.009022) with: {'batch_size': 202, 'epochs': 2000, 'optimizer__learning_rate': 0.0001, 'optimizer__momentum': 0.0}
# 0.880630 (0.024113) with: {'batch_size': 202, 'epochs': 2000, 'optimizer__learning_rate': 0.0001, 'optimizer__momentum': 0.3}
# 0.847884 (0.069668) with: {'batch_size': 202, 'epochs': 2000, 'optimizer__learning_rate': 0.0001, 'optimizer__momentum': 0.6}
# 0.827614 (0.051863) with: {'batch_size': 202, 'epochs': 2000, 'optimizer__learning_rate': 0.0001, 'optimizer__momentum': 0.9}
# 0.863965 (0.041851) with: {'batch_size': 202, 'epochs': 2000, 'optimizer__learning_rate': 0.001, 'optimizer__momentum': 0.0}
# 0.869088 (0.045414) with: {'batch_size': 202, 'epochs': 2000, 'optimizer__learning_rate': 0.001, 'optimizer__momentum': 0.3}
# 0.875797 (0.055643) with: {'batch_size': 202, 'epochs': 2000, 'optimizer__learning_rate': 0.001, 'optimizer__momentum': 0.6}
# 0.857790 (0.057164) with: {'batch_size': 202, 'epochs': 2000, 'optimizer__learning_rate': 0.001, 'optimizer__momentum': 0.9}
# 0.729818 (0.168990) with: {'batch_size': 202, 'epochs': 2000, 'optimizer__learning_rate': 0.01, 'optimizer__momentum': 0.0}
# 0.894654 (0.036148) with: {'batch_size': 202, 'epochs': 2000, 'optimizer__learning_rate': 0.01, 'optimizer__momentum': 0.3}
# 0.876285 (0.030580) with: {'batch_size': 202, 'epochs': 2000, 'optimizer__learning_rate': 0.01, 'optimizer__momentum': 0.6}
# 0.832756 (0.093833) with: {'batch_size': 202, 'epochs': 2000, 'optimizer__learning_rate': 0.01, 'optimizer__momentum': 0.9}
# 0.843075 (0.035592) with: {'batch_size': 202, 'epochs': 2000, 'optimizer__learning_rate': 0.1, 'optimizer__momentum': 0.0}
# 0.874462 (0.043517) with: {'batch_size': 202, 'epochs': 2000, 'optimizer__learning_rate': 0.1, 'optimizer__momentum': 0.3}
# 0.834353 (0.074426) with: {'batch_size': 202, 'epochs': 2000, 'optimizer__learning_rate': 0.1, 'optimizer__momentum': 0.6}
# 0.884068 (0.011276) with: {'batch_size': 202, 'epochs': 2000, 'optimizer__learning_rate': 0.1, 'optimizer__momentum': 0.9}
# 0.739596 (0.135287) with: {'batch_size': 202, 'epochs': 2000, 'optimizer__learning_rate': 0.3, 'optimizer__momentum': 0.0}
# 0.742983 (0.152866) with: {'batch_size': 202, 'epochs': 2000, 'optimizer__learning_rate': 0.3, 'optimizer__momentum': 0.3}
# 0.898225 (0.023283) with: {'batch_size': 202, 'epochs': 2000, 'optimizer__learning_rate': 0.3, 'optimizer__momentum': 0.6}
# 0.815557 (0.065985) with: {'batch_size': 202, 'epochs': 2000, 'optimizer__learning_rate': 0.3, 'optimizer__momentum': 0.9}

# %%
X.shape, Y.shape
# Out:
# ((202, 5), (202,))

# %%
# Use scikit-learn to grid search the batch size and epochs
import numpy as np
import tensorflow as tf
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from scikeras.wrappers import KerasRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.losses import mean_squared_error
# Function to create model, required for KerasClassifier
def create_model():

	def custom_loss(y_test, y_pred):
		squared_difference = tf.dtypes.cast(tf.square((y_test - y_pred)*weights), tf.float64) 
		return tf.dtypes.cast(tf.math.reduce_sum(squared_difference)/tf.math.reduce_sum(tf.square(weights)), tf.float64)  # Note the `axis=-1`

	# def custom_loss(y_true, y_pred):
	# 	return np.mean(weights * np.abs(y_true - y_pred))
    
	# create model
	model = Sequential()
	model.add(Dense(1, input_shape=(5,), activation=tf.keras.activations.linear))
    
    # Compile model
	model.compile(loss=custom_loss,
                  optimizer='adam',
                  # metrics=['mean_squared_error']
                 )
	return model
# fix random seed for reproducibility
seed = 7
tf.random.set_seed(seed)

# create model
model = KerasRegressor(model=create_model, epochs=1000, batch_size=202, verbose=0)
# define the grid search parameters
optimizer = ['adam']
learn_rate = [0.001, 0.01, 0.1]
momentum = [0.0, 0.3, 0.6, 0.9]
param_grid = dict(optimizer__learning_rate=learn_rate, optimizer__momentum=momentum)
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)

weights = 1/σrv_daily**2

# grid_result = grid.fit(X, Y, sample_weight=weights)
grid_result = grid.fit(X, Y)

# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x14f0880fb5b0> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x14f0880fb5b0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x14f0880fb5b0> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x14f0880fb5b0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x152f700e7520> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x152f700e7520>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x152f700e7520> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x152f700e7520>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x147559577520> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x147559577520>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x147559577520> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x147559577520>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x149ca41b7910> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x149ca41b7910>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x149ca41b7910> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x149ca41b7910>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x152d001079a0> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x152d001079a0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x152d001079a0> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x152d001079a0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x147d640ff9a0> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x147d640ff9a0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x147d640ff9a0> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x147d640ff9a0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x14ba800e7910> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x14ba800e7910>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x14ba800e7910> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x14ba800e7910>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x14a43677b9a0> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x14a43677b9a0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x14a43677b9a0> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x14a43677b9a0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x1504f4163910> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x1504f4163910>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x1504f4163910> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x1504f4163910>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x1509fc1d7910> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x1509fc1d7910>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x1509fc1d7910> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x1509fc1d7910>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x15416416f910> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x15416416f910>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x15416416f910> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x15416416f910>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x14f58c0ef910> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x14f58c0ef910>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x14f58c0ef910> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x14f58c0ef910>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x14ea741daa70> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x14ea741daa70>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x14ea741daa70> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x14ea741daa70>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x14f0600f2a70> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x14f0600f2a70>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x14f0600f2a70> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x14f0600f2a70>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x152a300ff520> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x152a300ff520>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x152a300ff520> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x152a300ff520>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x14faa01035b0> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x14faa01035b0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x14faa01035b0> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x14faa01035b0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x14a9f2b83520> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x14a9f2b83520>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x14a9f2b83520> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x14a9f2b83520>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x14edf81caa70> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x14edf81caa70>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x14edf81caa70> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x14edf81caa70>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x153fd81035b0> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x153fd81035b0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x153fd81035b0> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x153fd81035b0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x148dc00ff5b0> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x148dc00ff5b0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x148dc00ff5b0> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x148dc00ff5b0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x14dbc00e75b0> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x14dbc00e75b0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x14dbc00e75b0> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x14dbc00e75b0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x146b2415f5b0> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x146b2415f5b0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x15398810b5b0> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x15398810b5b0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x15398810b5b0> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x15398810b5b0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x146b2415f5b0> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x146b2415f5b0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x14645ff51870> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x14645ff51870>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x14645ff51870> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x14645ff51870>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x146d6c1db5b0> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x146d6c1db5b0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x146d6c1db5b0> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x146d6c1db5b0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x148f1475f5b0> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x148f1475f5b0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x148f1475f5b0> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x148f1475f5b0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x14844ec75870> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x14844ec75870>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x14844ec75870> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x14844ec75870>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x153f641cb5b0> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x153f641cb5b0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x153f641cb5b0> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x153f641cb5b0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x1461b0131870> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x1461b0131870>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x1461b0131870> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x1461b0131870>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x15119c0e7520> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x15119c0e7520>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x15119c0e7520> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x15119c0e7520>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x1485380f75b0> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x1485380f75b0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x1485380f75b0> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x1485380f75b0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x15146c0eb5b0> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x15146c0eb5b0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x15146c0eb5b0> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x15146c0eb5b0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x14acbc1075b0> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x14acbc1075b0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x14acbc1075b0> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x14acbc1075b0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x15361c1df520> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x15361c1df520>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x15361c1df520> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x15361c1df520>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x14ae541db520> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x14ae541db520>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x14ae541db520> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x14ae541db520>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x14b8d01d35b0> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x14b8d01d35b0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function create_model.<locals>.custom_loss at 0x14b8d01d35b0> and will run it as-is.
# Cause: Unable to locate the source code of <function create_model.<locals>.custom_loss at 0x14b8d01d35b0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Best: 0.805696 using {'optimizer__learning_rate': 0.01, 'optimizer__momentum': 0.0}
# -0.682823 (1.278141) with: {'optimizer__learning_rate': 0.001, 'optimizer__momentum': 0.0}
# -0.351709 (1.138020) with: {'optimizer__learning_rate': 0.001, 'optimizer__momentum': 0.3}
# -1.281775 (1.441441) with: {'optimizer__learning_rate': 0.001, 'optimizer__momentum': 0.6}
# -0.565316 (1.076964) with: {'optimizer__learning_rate': 0.001, 'optimizer__momentum': 0.9}
# 0.805696 (0.110063) with: {'optimizer__learning_rate': 0.01, 'optimizer__momentum': 0.0}
# 0.616668 (0.168868) with: {'optimizer__learning_rate': 0.01, 'optimizer__momentum': 0.3}
# -0.020948 (0.461163) with: {'optimizer__learning_rate': 0.01, 'optimizer__momentum': 0.6}
# -3.244741 (3.165169) with: {'optimizer__learning_rate': 0.01, 'optimizer__momentum': 0.9}
# -2.627132 (1.159269) with: {'optimizer__learning_rate': 0.1, 'optimizer__momentum': 0.0}
# -0.928265 (1.295028) with: {'optimizer__learning_rate': 0.1, 'optimizer__momentum': 0.3}
# 0.029983 (0.871972) with: {'optimizer__learning_rate': 0.1, 'optimizer__momentum': 0.6}
# -1.945383 (0.915807) with: {'optimizer__learning_rate': 0.1, 'optimizer__momentum': 0.9}

# %%
# Use scikit-learn to grid search the batch size and epochs
import numpy as np
import tensorflow as tf
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from scikeras.wrappers import KerasRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.losses import mean_squared_error
# Function to create model, required for KerasClassifier
def create_model():
	# create model
	model = Sequential()
	model.add(Dense(1, input_shape=(5,), activation=tf.keras.activations.linear))
    
    # Compile model
	model.compile(loss=mean_squared_error,
                  optimizer='adam',
                  metrics=['mean_squared_error']
                 )
	return model
# fix random seed for reproducibility
seed = 7
tf.random.set_seed(seed)

# create model
model = KerasRegressor(model=create_model, epochs=2000, batch_size=202, verbose=0)
# define the grid search parameters
optimizer = ['adam']
learn_rate = [0.001, 0.01, 0.1, 0.2, 0.3]
momentum = [0.0, 0.2, 0.4, 0.6, 0.8, 0.9]
param_grid = dict(optimizer__learning_rate=learn_rate, optimizer__momentum=momentum)
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)
grid_result = grid.fit(X, Y)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# 2023-03-14 14:51:43.392546: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:51:43.438374: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:51:43.440462: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# Best: 0.899042 using {'optimizer__learning_rate': 0.01, 'optimizer__momentum': 0.0}
# 0.881723 (0.045812) with: {'optimizer__learning_rate': 0.001, 'optimizer__momentum': 0.0}
# 0.812971 (0.049536) with: {'optimizer__learning_rate': 0.001, 'optimizer__momentum': 0.2}
# 0.779090 (0.101227) with: {'optimizer__learning_rate': 0.001, 'optimizer__momentum': 0.4}
# 0.809841 (0.138660) with: {'optimizer__learning_rate': 0.001, 'optimizer__momentum': 0.6}
# 0.873778 (0.005919) with: {'optimizer__learning_rate': 0.001, 'optimizer__momentum': 0.8}
# 0.767802 (0.138839) with: {'optimizer__learning_rate': 0.001, 'optimizer__momentum': 0.9}
# 0.899042 (0.021844) with: {'optimizer__learning_rate': 0.01, 'optimizer__momentum': 0.0}
# 0.705590 (0.146432) with: {'optimizer__learning_rate': 0.01, 'optimizer__momentum': 0.2}
# 0.846267 (0.042786) with: {'optimizer__learning_rate': 0.01, 'optimizer__momentum': 0.4}
# 0.873101 (0.050319) with: {'optimizer__learning_rate': 0.01, 'optimizer__momentum': 0.6}
# 0.827046 (0.038370) with: {'optimizer__learning_rate': 0.01, 'optimizer__momentum': 0.8}
# 0.749868 (0.169441) with: {'optimizer__learning_rate': 0.01, 'optimizer__momentum': 0.9}
# 0.852407 (0.058555) with: {'optimizer__learning_rate': 0.1, 'optimizer__momentum': 0.0}
# 0.808045 (0.104994) with: {'optimizer__learning_rate': 0.1, 'optimizer__momentum': 0.2}
# 0.865987 (0.023184) with: {'optimizer__learning_rate': 0.1, 'optimizer__momentum': 0.4}
# 0.771045 (0.100574) with: {'optimizer__learning_rate': 0.1, 'optimizer__momentum': 0.6}
# 0.744676 (0.075510) with: {'optimizer__learning_rate': 0.1, 'optimizer__momentum': 0.8}
# 0.831568 (0.076082) with: {'optimizer__learning_rate': 0.1, 'optimizer__momentum': 0.9}
# 0.873999 (0.042177) with: {'optimizer__learning_rate': 0.2, 'optimizer__momentum': 0.0}
# 0.703995 (0.230988) with: {'optimizer__learning_rate': 0.2, 'optimizer__momentum': 0.2}
# 0.799241 (0.088631) with: {'optimizer__learning_rate': 0.2, 'optimizer__momentum': 0.4}
# 0.747710 (0.115676) with: {'optimizer__learning_rate': 0.2, 'optimizer__momentum': 0.6}
# 0.796623 (0.098539) with: {'optimizer__learning_rate': 0.2, 'optimizer__momentum': 0.8}
# 0.806570 (0.048890) with: {'optimizer__learning_rate': 0.2, 'optimizer__momentum': 0.9}
# 0.794580 (0.058142) with: {'optimizer__learning_rate': 0.3, 'optimizer__momentum': 0.0}
# 0.737154 (0.017184) with: {'optimizer__learning_rate': 0.3, 'optimizer__momentum': 0.2}
# 0.753390 (0.089276) with: {'optimizer__learning_rate': 0.3, 'optimizer__momentum': 0.4}
# 0.858569 (0.071571) with: {'optimizer__learning_rate': 0.3, 'optimizer__momentum': 0.6}
# 0.855397 (0.039715) with: {'optimizer__learning_rate': 0.3, 'optimizer__momentum': 0.8}
# 0.884991 (0.042907) with: {'optimizer__learning_rate': 0.3, 'optimizer__momentum': 0.9}

# %%
# Use scikit-learn to grid search the batch size and epochs
import numpy as np
import tensorflow as tf
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from scikeras.wrappers import KerasRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.losses import mean_squared_error
# from keras.optimizers 
from tensorflow.keras.optimizers import Adam
# Function to create model, required for KerasClassifier
def create_model(activation='relu'):
	# create model
	model = Sequential()
	model.add(Dense(1, input_shape=(5,), activation=activation))
    
	adam = Adam(learning_rate=0.3)
    # Compile model
	model.compile(loss=mean_squared_error,
                  optimizer=adam,
                  metrics=['mean_squared_error']
                 )
	return model
# fix random seed for reproducibility
seed = 7
tf.random.set_seed(seed)

# create model
model = KerasRegressor(model=create_model, epochs=2000, batch_size=202, verbose=0)
# define the grid search parameters
activation = ['softmax', 'softplus', 'softsign', 'relu', 'tanh', 'sigmoid', 'hard_sigmoid', 'linear']
param_grid = dict(model__activation=activation)
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)
grid_result = grid.fit(X, Y)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.897722 using {'model__activation': 'linear'}
# -0.115580 (0.046244) with: {'model__activation': 'softmax'}
# 0.407638 (0.050862) with: {'model__activation': 'softplus'}
# 0.445458 (0.007642) with: {'model__activation': 'softsign'}
# 0.423566 (0.051077) with: {'model__activation': 'relu'}
# 0.424863 (0.011114) with: {'model__activation': 'tanh'}
# 0.219975 (0.025231) with: {'model__activation': 'sigmoid'}
# 0.218111 (0.028783) with: {'model__activation': 'hard_sigmoid'}
# 0.897722 (0.024293) with: {'model__activation': 'linear'}

# %%
print(tf.__version__)
# Out:
# 2.11.0

# %%
# Use scikit-learn to grid search the batch size and epochs
import numpy as np
import tensorflow as tf
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from scikeras.wrappers import KerasRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.losses import mean_squared_error
# Function to create model, required for KerasClassifier
def create_model(activation='relu'):
	# create model
	model = Sequential()
	model.add(Dense(1, input_shape=(5,), activation=activation))
    
    # Compile model
	model.compile(loss=mean_squared_error,
                  optimizer='adam',
                  metrics=['mean_squared_error']
                 )
	return model
# fix random seed for reproducibility
seed = 7
tf.random.set_seed(seed)

# create model
model = KerasRegressor(model=create_model, epochs=2000, batch_size=10, verbose=0)
# define the grid search parameters
activation = ['softmax', 'softplus', 'softsign', 'relu', 'tanh', 'sigmoid', 'hard_sigmoid', 'linear']
param_grid = dict(model__activation=activation)
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)
grid_result = grid.fit(X, Y)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# 2023-03-14 14:51:57.941635: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:51:57.944378: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:51:57.968937: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:51:57.972888: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:51:57.974063: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:51:57.975049: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:51:57.976203: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:51:57.998954: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2023-03-14 14:51:57.999927: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# Best: 0.898243 using {'model__activation': 'linear'}
# -0.115580 (0.046244) with: {'model__activation': 'softmax'}
# 0.407727 (0.051735) with: {'model__activation': 'softplus'}
# 0.443683 (0.010103) with: {'model__activation': 'softsign'}
# 0.424503 (0.051612) with: {'model__activation': 'relu'}
# 0.451031 (0.017417) with: {'model__activation': 'tanh'}
# 0.226059 (0.028831) with: {'model__activation': 'sigmoid'}
# 0.226412 (0.028389) with: {'model__activation': 'hard_sigmoid'}
# 0.898243 (0.024743) with: {'model__activation': 'linear'}

# %%
# Use scikit-learn to grid search the batch size and epochs
import numpy as np
import tensorflow as tf
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from scikeras.wrappers import KerasRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.losses import mean_squared_error
# Function to create model, required for KerasClassifier
def create_model(neurons):
	# create model
	model = Sequential()
	model.add(Dense(neurons, input_shape=(5,), kernel_initializer='uniform', activation=tf.keras.activations.linear))
	model.add(Dense(1, kernel_initializer='uniform', activation=tf.keras.activations.linear))
    
    # Compile model
	model.compile(loss=mean_squared_error,
                  optimizer='adam',
                  metrics=['mean_squared_error']
                 )
	return model
# fix random seed for reproducibility
seed = 7
tf.random.set_seed(seed)

# create model
model = KerasRegressor(model=create_model, epochs=2000, batch_size=10, verbose=0)
# define the grid search parameters
neurons = [1, 5, 10, 15, 20, 25, 30]
param_grid = dict(model__neurons=neurons)
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)
grid_result = grid.fit(X, Y)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.898503 using {'model__neurons': 5}
# 0.897857 (0.024254) with: {'model__neurons': 1}
# 0.898503 (0.025293) with: {'model__neurons': 5}
# 0.896964 (0.024452) with: {'model__neurons': 10}
# 0.895869 (0.023831) with: {'model__neurons': 15}
# 0.895633 (0.023772) with: {'model__neurons': 20}
# 0.896917 (0.022533) with: {'model__neurons': 25}
# 0.898327 (0.022821) with: {'model__neurons': 30}
