# %%
import sys
sys.path.append('../src')

import numpy as np
import matplotlib.pyplot as plt
from PyAstronomy import pyasl
from datetime import datetime

from FIESTA_functions import *
from HARPS_N_functions import *
from NEID_solar_functions import *
from functions import *
#----------------------------------
# Read data
#----------------------------------

# %%
if 1:
    v_grid  = np.loadtxt('../lib/data_v4/v_grid.txt')
    CCF     = np.loadtxt('../lib/data_v4/CCF.txt')
    σCCF   = np.loadtxt('../lib/data_v4/σCCF.txt')
    bjd     = np.loadtxt('../lib/data_v4/bjd.txt')
    rv      = np.loadtxt('../lib/data_v4/rv.txt')
    σrv     = np.loadtxt('../lib/data_v4/σrv.txt')
    idx_rej = np.array(np.loadtxt('../lib/data_v4/idx_rej'), dtype=bool)
    
    # idx_v = (v_grid>90.25) & (v_grid<107.5)
    # v_grid = v_grid[idx_v]
    
    CCF = CCF[:,~idx_rej]
    σCCF = σCCF[:,~idx_rej]
    # CCF = CCF[idx_v,:]
    # σCCF = σCCF[idx_v,:]    
    bjd = bjd[~idx_rej]
    rv = rv[~idx_rej]
    σrv = σrv[~idx_rej]

# %%
plt.plot(v_grid, CCF[:,0], '.')
plt.show()

# %%
t_min = int(min(bjd))
t_max = int(max(bjd))
N = t_max -t_min + 1

bjd_daily 			= np.zeros(N)
CCF_daily 			= np.zeros((len(v_grid), N))
σCCF_daily			= np.zeros((len(v_grid), N))
rv_daily			= np.zeros(N)
# rv_raw_daily		= np.zeros(N)
σrv_daily			= np.zeros(N)

for n in range(N):
    idx = (bjd>(t_min+n)) & (bjd<(t_min+n+0.5))
    if len(bjd[idx])!=0:
        bjd_daily[n] = weighted_avg_1D(bjd[idx], 1/σrv[idx]**2)
        rv_daily[n] =  weighted_avg_1D(rv[idx], 1/σrv[idx]**2)
        σrv_daily[n] = 1/np.sqrt(np.sum(1/σrv[idx]**2))
        CCF_daily[:,n] = 1-weighted_avg_2D(1-CCF[:,idx], 1/σrv[idx]**2)
        σCCF_daily[:,n] = 1/np.sqrt(np.sum(1/σCCF[:,idx]**2, axis=1))

idx_0 		= (rv_daily==0)
rv_daily 	= rv_daily[~idx_0]
# rv_raw_daily= rv_raw_daily[~idx_0]
σrv_daily 	= σrv_daily[~idx_0]
bjd_daily 	= bjd_daily[~idx_0]
CCF_daily 	= CCF_daily[:,~idx_0]
σCCF_daily 	= σCCF_daily[:,~idx_0]

# %%
CCF_daily.shape
# Out:
# (95, 202)

# %%
np.median((1-CCF_daily) / σCCF_daily)
# Out:
# 74807.5655805018

# %%
from scipy.interpolate import CubicSpline

# CCF_tpl = np.mean(CCF_daily, axis=1)
CCF_tpl = CCF_daily[:,0]
cs = CubicSpline(v_grid, CCF_tpl, extrapolate=True)

CCF_daily_sh = np.zeros(CCF_daily.shape)
σCCF_daily_sh = np.zeros(CCF_daily.shape)

shift = np.arange(202)/202/100
print(max(shift)*1000)
for i in range(202):
    CCF_daily_sh[:,i] = cs(v_grid-shift[i])
    σCCF_daily_sh[:,i] = (1-CCF_tpl)**0.5/7e4
# Out:
# 9.950495049504951

# %%
plt.plot(σCCF_daily_sh, 'o')
plt.plot(σCCF_daily, '.', alpha=0.05)
plt.show()

# %%
# plt.plot(CCF_daily_wn-np.mean(CCF_daily_wn, axis=1), '.')

# plt.plot(np.mean(CCF_daily_wn, axis=1), '.') 
for i in np.linspace(0,202,10, endpoint=False):
    i = int(i)
    plt.plot(CCF_daily_sh[:,i]-np.mean(CCF_daily_sh, axis=1), '-', label=str(i)) 
plt.legend(loc=1)    
plt.show()

# %%
CCF_daily_sh.shape
# Out:
# (95, 202)

# %%
k_max = 47
df, RV_FT_k, eRV_FT_k, A_k, eA_k, RV_gauss = FIESTA(v_grid, CCF_daily_sh, σCCF_daily_sh/10, k_max=k_max)

order_max = 47
RV_FIESTA = np.average(RV_FT_k[:order_max], axis=0, weights=A_k[:order_max])*1000
print(np.mean(A_k[order_max-1]))

RV_FT_k  *= 1000
eRV_FT_k *= 1000
RV_gauss *= 1000
ΔRV_k     = RV_FT_k - RV_FIESTA
# Out:
# Velocity grid used [87.25, 110.75]
#
# ξ_normal = 1.98
#
#
# The median SNR of all CCFs is 672440
# ξ_modelling_noise = 1.98
#
#
# Based on the user-defined SNR = 2.0:
# ξ_individual = 1.98
# ξ_timeseries = 0.21
#
# In summary, the cut-off frequency for FIESTA is recommended to be 0.21 (5 frequency modes)
#
#         ξ  individual_SNR  ts_SNR_A  ts_SNR_ϕ  modelling noise  \
# 0   0.000       1474004.6       6.4       0.0          0.13634
# 1   0.042        937875.3       6.4     716.8          0.04865
# 2   0.084        347452.7       6.3     529.2          0.01187
# 3   0.126         85572.2       6.2     197.9          0.00243
# 4   0.168         17461.2       5.1      49.4          0.00054
# 5   0.211          1252.5       6.5       5.1          0.00051
# 6   0.253          1786.0       1.0       1.8          0.00045
# 7   0.295          1144.0       0.1       0.4          0.00042
# 8   0.337          1082.3       0.9       0.2          0.00039
# 9   0.379           945.7       0.4       0.0          0.00037
# 10  0.421           887.9       0.6       0.2          0.00035
# 11  0.463           828.0       0.4       0.4          0.00033
# 12  0.505           723.8       0.7       0.1          0.00032
# 13  0.547           670.0       0.4       0.0          0.00030
# 14  0.589           635.9       0.2       0.1          0.00029
# 15  0.632           599.0       0.2       0.1          0.00028
# 16  0.674           563.5       0.3       0.1          0.00027
# 17  0.716           519.5       0.2       0.0          0.00026
# 18  0.758           493.9       0.4       0.0          0.00025
# 19  0.800           471.2       0.3       0.0          0.00024
# 20  0.842           452.6       0.5       0.0          0.00023
# 21  0.884           432.9       0.3       0.0          0.00022
# 22  0.926           418.1       0.2       0.0          0.00022
# 23  0.968           402.3       0.3       0.0          0.00021
# 24  1.011           388.5       0.3       0.0          0.00020
# 25  1.053           379.4       0.3       0.0          0.00020
# 26  1.095           363.3       0.2       0.1          0.00019
# 27  1.137           353.1       0.2       0.1          0.00018
# 28  1.179           348.9       0.2       0.0          0.00018
# 29  1.221           332.9       0.3       0.2          0.00017
# 30  1.263           339.2       0.4       0.1          0.00017
# 31  1.305           299.6       0.4       0.5          0.00016
# 32  1.347           359.1       1.6       0.9          0.00015
# 33  1.389           337.3       1.1       0.6          0.00015
# 34  1.432           305.4       0.3       0.0          0.00014
# 35  1.474           276.6       2.0       0.3          0.00014
# 36  1.516           329.5       0.7       0.7          0.00013
# 37  1.558           288.7       0.7       0.1          0.00012
# 38  1.600           255.5       0.5       0.6          0.00012
# 39  1.642           337.7       0.2       0.8          0.00011
# 40  1.684           285.0       0.7       0.1          0.00010
# 41  1.726           273.8       0.2       0.2          0.00009
# 42  1.768           288.5       0.2       0.1          0.00009
# 43  1.811           281.9       0.2       0.0          0.00008
# 44  1.853           281.6       0.2       0.0          0.00007
# 45  1.895           280.2       0.2       0.0          0.00005
# 46  1.937           279.5       0.2       0.0          0.00004
# 47  1.979           279.3       0.2       0.0          0.00000
#
#     recoverable_CCF_SNR
# 0                     7
# 1                    19
# 2                    78
# 3                   380
# 4                  1725
# 5                  1819
# 6                  2071
# 7                  2209
# 8                  2360
# 9                  2499
# 10                 2644
# 11                 2793
# 12                 2925
# 13                 3055
# 14                 3188
# 15                 3321
# 16                 3455
# 17                 3582
# 18                 3710
# 19                 3839
# 20                 3971
# 21                 4104
# 22                 4242
# 23                 4382
# 24                 4527
# 25                 4678
# 26                 4832
# 27                 4992
# 28                 5164
# 29                 5338
# 30                 5538
# 31                 5711
# 32                 5990
# 33                 6273
# 34                 6538
# 35                 6783
# 36                 7182
# 37                 7541
# 38                 7864
# 39                 8543
# 40                 9151
# 41                 9844
# 42                10835
# 43                12129
# 44                14030
# 45                17199
# 46                24332
# 47    26356980027585912
# 0.0025481630065552303

# %%
np.std(RV_gauss)
# Out:
# 2.887356098564402

# %%
plot_all(k_mode=k_max, t=np.arange(202), rv=RV_gauss, erv=σrv_daily*0.01, 
    ind=A_k, eind=eA_k, 
    ts_xlabel='BJD - 2400000 [d]', 
    rv_xlabel='$RV_{gaussian}$', 
    pe_xlabel='Period [days]',
    ind_yalbel='A',
    file_name='',
    HARPS=False)
plt.show()

# %%
plot_all(k_mode=k_max, t=np.arange(202), rv=RV_gauss, erv=σrv_daily*0.01, 
    ind=ΔRV_k, eind=eRV_FT_k/1000, 
    ts_xlabel='BJD - 2400000 [d]', 
    rv_xlabel='$RV_{gaussian}$', 
    pe_xlabel='Period [days]',
    ind_yalbel=r'$\Delta RV$',
    file_name='',
    HARPS=False)
plt.show()

# %%
plot_all(k_mode=k_max, t=np.arange(202), rv=RV_gauss, erv=σrv_daily*0.01, 
    ind=RV_FT_k, eind=eRV_FT_k/1000, 
    ts_xlabel='BJD - 2400000 [d]', 
    rv_xlabel='$RV_{gaussian}$', 
    pe_xlabel='Period [days]',
    ind_yalbel=r'$RV_{FT}$',
    file_name='',
    HARPS=False)
plt.show()

# %%
[max(RV_FT_k[i])-min(RV_FT_k[i]) for i in range(47) ]
# Out:
# [9.957755948301646,
#  9.922751026790614,
#  10.046017772415091,
#  9.212475344505783,
#  10.680507551565782,
#  2.160630563551381,
#  0.6267591907133949,
#  0.23121363098656222,
#  0.04371947713588348,
#  0.35346973916706725,
#  0.541856001356009,
#  0.0779349234184736,
#  0.027241619855430263,
#  0.17852005126289033,
#  0.2135179649437932,
#  0.19783090549008614,
#  0.07074126808476619,
#  0.05673336903591707,
#  0.06311290474247268,
#  0.013225572002235229,
#  0.06150911969880905,
#  0.028711875522935963,
#  0.049477544853017294,
#  0.0637362043638671,
#  0.011657035627490136,
#  0.12144754261839677,
#  0.12981448220404948,
#  0.002029981956239287,
#  0.20691148490658534,
#  0.16162952552218485,
#  0.7088781295023543,
#  1.039337882620354,
#  0.7179736173799656,
#  0.05719465846649103,
#  0.4014633975913385,
#  0.724845348990119,
#  0.1705724095702103,
#  0.7683809379379942,
#  0.756399490237313,
#  0.06125893993475985,
#  0.18264718469828672,
#  0.06494937668486753,
#  0.0006624655496349585,
#  0.006069885075180324,
#  0.001500352985126375,
#  0.0011044993167467145,
#  0.0004677253130928455]

# %%
plt.plot(RV_FIESTA, '.', label='fiesta')
plt.plot(RV_gauss, '.', label='gaussian')
plt.show()

# %%
plt.plot(RV_FIESTA-RV_gauss, '.', label='gaussian')
plt.show()

# %%
plt.plot(RV_gauss, RV_FIESTA, '.')
plt.show()

# %%
np.std(RV_FIESTA-RV_gauss), np.std(RV_FIESTA), np.std(RV_gauss)
# Out:
# (0.04320040803091624, 2.8441557020726265, 2.887356098564402)

# %%
plt.plot(RV_gauss, RV_FT_k[0:5].T, '.')
plt.show()

# %%
plt.plot(A_k[:10,], '.')
plt.show()

# %%
RV_FT_k.shape
# Out:
# (47, 202)
